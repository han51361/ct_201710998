# %%
from PIL import image
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-a7b501ac7f01> in <module>()
# ----> 1 from PIL import image
#
# ImportError: cannot import name image

# %%
print "Hello"

# %%
from PIL import Image

# %%
m = Image.open("C:\\Users\\400T6B\\Downloads\\italy-1587287_1920.jpg")

# %%
m.show()

# %% [markdown]
# * jpg 파일을 gif 파일로 변환하기
#     * 파일확장자를 gif로 적어둔다

# %% [markdown]
# *operate overloading
#     *'+'가 숫자를 만나면 합산, 문자를 만나면 합성, 경우에 따라서 여러가지 기능 수행

# %%
m.save("C:\\Users\\400T6B\\Downloads\\italy-1587287_1920.gif")

# %%
m.show()

# %%
# %matplotlib inline
from matplotlib.pyplot import imshow
imshow(m)

# %%
<matplotlib.image.AxesImage at 0x92a0f28>
# Out:
#   File "<ipython-input-25-ff3bf7f919f4>", line 1
#     <matplotlib.image.AxesImage at 0x92a0f28>
#     ^
# SyntaxError: invalid syntax

# %%
print "Hello" + "World"
# Out:
# HelloWorld

# %%
print "Hello" *3
# Out:
# HelloHelloHello

# %% [markdown]
# * startswith() 기능 배우기

# %%
s = "Hello world"
s.startswith('H')
# Out:
# True

# %% [markdown]
# * 대소문자 식별 기능
#     * Case senstive

# %%
s1 = "123"
print int(s1) + 1
# Out:
# 124

# %%
print s[0]
# Out:
# H

# %%
s.endswith('d')
# Out:
# True

# %%
for i in range(0,len(s)):
    print s[i],
# Out:
# H e l l o   w o r l d

# %%
s.index("wor")
# Out:
# 6

# %%
s.strip('rid')
# Out:
# 'Hello worl'

# %%
print s[-1]
# Out:
# d
